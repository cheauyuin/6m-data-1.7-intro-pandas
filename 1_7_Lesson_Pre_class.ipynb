# %% [markdown]
# <a href="https://colab.research.google.com/github/cheauyuin/6m-data-1.7-intro-pandas/blob/main/1_7_Lesson_Pre_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

print(f"Pandas version: {pd.__version__}")
print("✅ Environment is ready!")
# Out:
# Pandas version: 2.2.2
# ✅ Environment is ready!

# %%
import pandas as pd
# A simple list of data
data = [10, 20, 30, 40]
# Converting it to a Pandas Series
s = pd.Series(data, index=['a', 'b', 'c', 'd'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
# A dictionary where keys are column names
data = {
    'Apples': [3, 2, 0, 1],
    'Oranges': [0, 3, 7, 2]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Apples  Oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2
